# %%
# import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#"C:\Users\HP\Desktop\finance\project under prof\^HSI.csv" reading all csv files



#hongkong=pd.concat([hongkong,hongkong_post])

#print(shanghai.loc[:,'Close'])


malaysia=pd.read_csv('project under prof/^KLSE.csv',index_col='Date')
malaysia=malaysia.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])

malaysia_post=pd.read_csv('project under prof/1^KLSE.csv',index_col='Date')
malaysia_post=malaysia_post.loc['2020-08-07':'2020-11-13',:]
malaysia_post=malaysia_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
malaysia_pre=malaysia.loc['2019-10-15':'2020-03-11',:]
malaysia_during=malaysia.loc['2020-03-11':'2020-08-06',:]

#malaysia=pd.concat([malaysia,malaysia_post])

japan=pd.read_csv('project under prof\^N225 (2).csv',index_col='Date')
japan=japan.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
japan_post=pd.read_csv('project under prof/1^N225.csv',index_col='Date')
japan_post=japan_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
japan_pre=japan.loc['2019-10-15':'2020-03-11',:]
japan_during=japan.loc['2020-03-11':'2020-08-06',:]

#japan=pd.concat([japan,japan_post])
#japan=japan.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])


india=pd.read_csv('project under prof\^NSEI.csv',index_col='Date')
india=india.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
india_post=pd.read_csv("project under prof/1^NSEI.csv",index_col='Date')
india_post=india_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
india_pre=india.loc['2019-10-15':'2020-03-11',:]
india_during=india.loc['2020-03-11':'2020-08-06',:]

#india=pd.concat([india,india_post])

korea=pd.read_csv('project under prof\^KS11.csv',index_col='Date')
korea=korea.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
korea_post=pd.read_csv("project under prof/1^KS11.csv",index_col='Date')
korea_post=korea_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
korea_pre=korea.loc['2019-10-15':'2020-03-11',:]
korea_during=korea.loc['2020-03-11':'2020-08-06',:]

#korea=pd.concat([korea,korea_post])

shanghai=pd.read_csv("project under prof/shanghai.csv",index_col='Date')
shanghai=shanghai.iloc[::-1]
shanghai.loc[:,'Close']=shanghai.loc[:,'Price']
shanghai=shanghai.drop(columns=['Open', 'High', 'Low','Vol.', 'Change %','Price'])
print(shanghai.head())
shanghai_pre=shanghai.loc['2019-10-15':'2020-03-11',:]
shanghai_during=shanghai.loc['2020-03-11':'2020-08-06',:]
shanghai_post=shanghai.loc['2020-08-07':,:]

indonesia=pd.read_csv('project under prof\^JKSE.csv',index_col='Date')
indonesia=indonesia.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
indonesia_post=pd.read_csv("project under prof/1^JKSE.csv",index_col='Date')
indonesia_post=indonesia_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
indonesia_pre=indonesia.loc['2019-10-15':'2020-03-11',:]
indonesia_during=indonesia.loc['2020-03-11':'2020-08-06',:]

#indonesia=pd.concat([indonesia,indonesia_post])

"""bangladesh=pd.read_csv("project under prof/Dhaka Stock Exchange 30 Historical Data.csv",index_col='Date')
bangladesh.loc[:,'Close']=bangladesh.loc[:,'Price']
bangladesh=bangladesh.drop(columns=['Open', 'High', 'Low','Vol.', 'Change %','Price'])
bangladesh=bangladesh.iloc[::-1]
print(bangladesh.shape)
bangladesh_pre=bangladesh.loc['2019-10-15':'2020-03-11',:]
print(bangladesh_pre.shape)
bangladesh_during=bangladesh.loc['2020-03-11':'2020-08-06',:]
print(bangladesh_during.shape)
bangladesh_post=bangladesh.loc['2020-08-07':,:]
print(bangladesh_post.shape)
bangladesh=bangladesh.loc['2019-10-15':'2020-08-06',:]"""

pakistan=pd.read_csv('project under prof\^KSE.csv',index_col='Date')
pakistan=pakistan.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
pakistan_post=pd.read_csv("project under prof/1^KSE.csv",index_col='Date')
pakistan_post=pakistan_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
pakistan_pre=pakistan.loc['2019-10-15':'2020-03-11',:]
pakistan_during=pakistan.loc['2020-03-11':'2020-08-06',:]

#pakistan=pd.concat([pakistan,pakistan_post])

philippines=pd.read_csv('project under prof\PSEI.PS.csv',index_col='Date')
philippines=philippines.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
philippines_post=pd.read_csv("project under prof/1PSEI.PS.csv",index_col='Date')
philippines_post=philippines_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
philippines_pre=philippines.loc['2019-10-15':'2020-03-11',:]
philippines_during=philippines.loc['2020-03-11':'2020-08-06',:]

#philippines=pd.concat([philippines,philippines_post])

singapore=pd.read_csv('project under prof\^STI.csv',index_col='Date')
singapore=singapore.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
#singapore=singapore.loc['2019-10-15':'2020-08-06',:]
singapore_post=pd.read_csv("project under prof/1^STI.csv",index_col='Date')
singapore_post=singapore_post.loc['2020-08-07':,:]
singapore_post=singapore_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
singapore_pre=singapore.loc['2019-10-15':'2020-03-11',:]
singapore_during=singapore.loc['2020-03-11':'2020-08-06',:]

#singapore=pd.concat([singapore,singapore_post])

hongkong=pd.read_csv('project under prof\^HSI.csv',index_col='Date')
hongkong=hongkong.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
hongkong_post=pd.read_csv("project under prof/1^HSI.csv",index_col='Date')
hongkong_post=hongkong_post.drop(columns=['Open', 'High', 'Low','Adj Close', 'Volume'])
hongkong_pre=hongkong.loc['2019-10-15':'2020-03-11',:]
hongkong_during=hongkong.loc['2020-03-11':'2020-08-06',:]


#hongkong=pd.concat([hongkong,hongkong_post])

#
# Out:
#               Close
# Date
# 2019-10-15  2991.05
# 2019-10-16  2978.71
# 2019-10-17  2977.33
# 2019-10-18  2938.14
# 2019-10-21  2939.62

# %%
#lis=[malaysia,japan,india,bangladesh,korea,philippines,pakistan,indonesia,singapore,hongkong]
#lis2=['malaysia','japan','india','bangladesh','korea','philippines','pakistan','indonesia','singapore','hongkong']
lis=[malaysia,japan,india,korea,philippines,pakistan,indonesia,singapore,hongkong,shanghai]
lis2=['malaysia','japan','india','korea','philippines','pakistan','indonesia','singapore','hongkong','shanghai']
#shifting the close row by 1 to upside and calculating log returns
def shift(df):
    df['Shift']=df['Close'].shift(-1)
    df['logreturn']=np.log(df['Close']/df['Shift'])
    df.dropna()
    
    print(df.shape)
    return(df)
for i in range(len(lis)):
    shift(lis[i])
    lis[i]=lis[i].drop(columns=['Shift','Close'])
    print(lis[i].shape)
# Out:
# (268, 3)
# (268, 1)
# (263, 3)
# (263, 1)
# (272, 3)
# (272, 1)
# (270, 3)
# (270, 1)
# (284, 3)
# (284, 1)
# (275, 3)
# (275, 1)
# (265, 3)
# (265, 1)
# (370, 3)
# (370, 1)
# (269, 3)
# (269, 1)
# (265, 3)
# (265, 1)

# %%
"""lis3=[malaysia_pre,japan_pre,india_pre,bangladesh_pre,korea_pre,philippines_pre,pakistan_pre,indonesia_pre,singapore_pre,hongkong_pre,shanghai_pre]
lis4=[malaysia_during,japan_during,india_during,bangladesh_during,korea_during,philippines_during,pakistan_during,indonesia_during,singapore_during,hongkong_during,shanghai_during]
lis8=[malaysia_post,japan_post,india_post,bangladesh_post,korea_post,philippines_post,pakistan_post,indonesia_post,singapore_post,hongkong_post,shanghai_post]
lis2=['malaysia','japan','india','bangladesh','korea','philippines','pakistan','indonesia','singapore','hongkong']"""
lis3=[malaysia_pre,japan_pre,india_pre,korea_pre,philippines_pre,pakistan_pre,indonesia_pre,singapore_pre,hongkong_pre,shanghai_pre]
lis4=[malaysia_during,japan_during,india_during,korea_during,philippines_during,pakistan_during,indonesia_during,singapore_during,hongkong_during,shanghai_during]
lis8=[malaysia_post,japan_post,india_post,korea_post,philippines_post,pakistan_post,indonesia_post,singapore_post,hongkong_post,shanghai_post]
lis2=['malaysia','japan','india','korea','philippines','pakistan','indonesia','singapore','hongkong','shanghai']
#shifting the close row by 1 to upside and calculating log returns
def shift(df):
    df['Shift']=df['Close'].shift(-1)
    df['logreturn']=np.log(df['Close']/df['Shift'])
    df.dropna()
    
    #print(df.shape)
    return(df)
for i in range(len(lis3)):
    shift(lis3[i])
    lis3[i]=lis3[i].drop(columns=['Shift','Close'])
    #print(lis3[i].shape)
for j in range(len(lis4)):
    shift(lis4[j])
    lis4[j]=lis4[j].drop(columns=['Shift','Close'])
    print(lis4[j].shape)
for j in range(len(lis8)):
    shift(lis8[j])
    lis8[j]=lis8[j].drop(columns=['Shift','Close'])
    #print(lis8[j].shape)
# Out:
# (99, 1)
# (100, 1)
# (101, 1)
# (103, 1)
# (107, 1)
# (104, 1)
# (98, 1)
# (101, 1)
# (101, 1)
# (101, 1)
# <ipython-input-4-2f69764bc91e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Shift']=df['Close'].shift(-1)
# <ipython-input-4-2f69764bc91e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['logreturn']=np.log(df['Close']/df['Shift'])
# <ipython-input-4-2f69764bc91e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df=pd.concat(lis,axis=1,join='inner',keys=lis2)
lis1=df.index

for m in range(len(lis)):
    
    print("for the stock indice of "+lis2[m],df[lis2[m]].describe())
    print(df[lis2[m]].skew())
    print(df[lis2[m]].kurtosis())
df=df.dropna()
print(df.shape)
# Out:
# for the stock indice of malaysia         logreturn
# count  204.000000
# mean    -0.000191
# std      0.011708
# min     -0.066263
# 25%     -0.005526
# 50%     -0.000276
# 75%      0.004712
# max      0.054047
# logreturn    0.081578
# dtype: float64
# logreturn    8.330229
# dtype: float64
# for the stock indice of japan         logreturn
# count  204.000000
# mean    -0.000875
# std      0.015811
# min     -0.077314
# 25%     -0.007343
# 50%     -0.000904
# 75%      0.005742
# max      0.062736
# logreturn   -0.352062
# dtype: float64
# logreturn    5.919812
# dtype: float64
# for the stock indice of india         logreturn
# count  203.000000
# mean    -0.000834
# std      0.018335
# min     -0.084003
# 25%     -0.008531
# 50%     -0.001869
# 75%      0.004350
# max      0.086669
# logreturn    0.554645
# dtype: float64
# logreturn    6.814999
# dtype: float64
# for the stock indice of korea         logreturn
# count  202.000000
# mean    -0.001281
# std      0.017724
# ...

# %%
fig,ax=plt.subplots(4,3)
lisk=[]
for j in range(8):
    lisk.append(df.index[24*j])

for i in range(3):
    ax[0][i].plot(df.index,df[lis2[i]])
    ax[0][i].set_xlabel(lis2[i])
    ax[0][i].set_xticks(lisk)
    ax[0][i].set_xticklabels(['Sept 2019','Nov 2019','Jan 2020','Mar 2020','May 2020','Jul 2020','Sept 2020','Nov 2020'],rotation=45)
    #ax[0][i].set_title(lis2[i])
for i in range(3,6):
    ax[1][i-3].plot(df.index,df[lis2[i]])
    ax[1][i-3].set_xlabel(lis2[i])
    ax[1][i-3].set_xticks(lisk)
    ax[1][i-3].set_xticklabels(['Sept 2019','Nov 2019','Jan 2020','Mar 2020','May 2020','Jul 2020','Sept 2020','Nov 2020'],rotation=45)
    #ax[1][i-3].set_title(lis2[i])
    
ax[3][0].plot(df.index,df[lis2[6]])
ax[3][0].set_xlabel(lis2[6])
ax[3][0].set_xticks(lisk)
ax[3][0].set_xticklabels(['Sept 2019','Nov 2019','Jan 2020','Mar 2020','May 2020','Jul 2020','Sept 2020','Nov 2020'],rotation=45)
#ax[2][0].set_title(lis2[6])

for i in range(7,10):
    ax[2][i-7].plot(df.index,df[lis2[i]])
    ax[2][i-7].set_xlabel(lis2[i])
    ax[2][i-7].set_xticks(lisk)
    ax[2][i-7].set_xticklabels(['Sept 2019','Nov 2019','Jan 2020','Mar 2020','May 2020','Jul 2020','Sept 2020','Nov 2020'],rotation=45)
    #ax[1][i-3].set_title(lis2[i])
fig.delaxes(ax[3][1])
fig.delaxes(ax[3][2])
plt.subplots_adjust(top=1.5)
fig.set_size_inches(30,20)
plt.show()

# %%
df_pre=pd.concat(lis3,axis=1,join='inner',keys=lis2)
for m in range(len(lis2)):
    
    print("for the stock indice of "+lis2[m],df_pre[lis2[m]].describe())
    print(df_pre[lis2[m]].skew())
    print(df_pre[lis2[m]].kurtosis())
df_pre=df_pre.dropna()
print(df_pre.shape)

# %%
df_during=pd.concat(lis4,axis=1,join='inner',keys=lis2)
for m in range(len(lis2)):
    
    print("for the stock indice of "+lis2[m],df_during[lis2[m]].describe())
    print(df_during[lis2[m]].skew())
    print(df_during[lis2[m]].kurtosis())
df_during=df_during.dropna()
print(df_during.shape)

# %%
df_post=pd.concat(lis8,axis=1,join='inner',keys=lis2)
for m in range(len(lis2)):
    
    print("for the stock indice of "+lis2[m],df_post[lis2[m]].describe())
    print(df_post[lis2[m]].skew())
    print(df_post[lis2[m]].kurtosis())


df_post=df_post.dropna()
print(df_post.shape)
print(df_post.head())

# %%
import math
#finding skewness kurtosis JB statistics anf ADF unit test
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.stattools import jarque_bera
import seaborn as sns
#making a new empty dataframe which will not be having multi index columns with index as date then using for loop to add logreturns of all stock indices from the df which we found by concatenation
data=pd.DataFrame(index=df.index)
for t in range(len(lis2)):
    data[lis2[t]+'_logreturn']=df[lis2[t]]['logreturn']
print(data.shape)
hierarchical = sns.clustermap(data)
plt.show()
heatmap = sns.heatmap(data.corr(),xticklabels=lis2, yticklabels=lis2, annot=True, cmap='BrBG')
fig = heatmap.get_figure()
plt.show()
corr_matrix=data.corr()
#dist_matrix=math.sqrt(2*(1-corr_matrix))
print(corr_matrix)
#fig.savefig("correlation.png")
for a in range(len(lis2)):
    
    adf=adfuller(data.dropna()[lis2[a]+"_logreturn"])
    jb=jarque_bera(data.dropna()[lis2[a]+'_logreturn'])
    print('\nADF test for logreturns on stock indice of '+lis2[a])
    print('ADF value is ',adf[0])
    print('Pvalue is ',adf[1])
    print('Critical values are ',adf[4])
    print('\nJB statistics for logreturns on stock indice of '+lis2[a],jb[0])

# %%
import math
#finding skewness kurtosis JB statistics anf ADF unit test
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.stattools import jarque_bera
import seaborn as sns
#making a new empty dataframe which will not be having multi index columns with index as date then using for loop to add logreturns of all stock indices from the df which we found by concatenation
data_pre=pd.DataFrame(index=df_pre.index)
for t in range(len(lis2)):
    data_pre[lis2[t]+' pre_logreturn']=df_pre[lis2[t]]['logreturn']
print(data_pre.shape)
hierarchical_pre = sns.clustermap(data_pre)
plt.show()
heatmap_pre = sns.heatmap(data_pre.corr(),xticklabels=lis2, yticklabels=lis2, annot=True, cmap='BrBG')
fig = heatmap_pre.get_figure()
plt.show()
corr_matrix_pre=data_pre.corr()
#dist_matrix=math.sqrt(2*(1-corr_matrix))
print(corr_matrix_pre)
#fig.savefig("correlation.png")
adf_pre=pd.DataFrame(index=lis2)


for a in range(len(lis2)):
    
    adft=adfuller(data_pre.dropna()[lis2[a]+" pre_logreturn"])
    jbt=jarque_bera(data_pre.dropna()[lis2[a]+' pre_logreturn'])
    adf_pre.loc[lis2[a],'ADF value']=adft[0]
    adf_pre.loc[lis2[a],'P value']=adft[1]
    adf_pre.loc[lis2[a],'Critical value 1%']=adft[4].get('1%')
    adf_pre.loc[lis2[a],'Critical value 5%']=adft[4].get('5%')
    adf_pre.loc[lis2[a],'Critical value 10%']=adft[4].get('10%')
    adf_pre.loc[lis2[a],'JB Statistics']=jbt[0]
    print('\nADF test for logreturns on stock indice of '+lis2[a])
    print('ADF value is ',adft[0])
    print('Pvalue is ',adft[1])
    print('Critical values are ',adft[4])
    print('\nJB statistics for logreturns on stock indice of '+lis2[a],jbt[0])
print(adf_pre.head())

# %%
import math
#finding skewness kurtosis JB statistics anf ADF unit test
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.stattools import jarque_bera
import seaborn as sns
#making a new empty dataframe which will not be having multi index columns with index as date then using for loop to add logreturns of all stock indices from the df which we found by concatenation
data_during=pd.DataFrame(index=df_during.index)
for t in range(len(lis2)):
    data_during[lis2[t]+' during_logreturn']=df_during[lis2[t]]['logreturn']
print(data_during.head())
hierarchical_during = sns.clustermap(data_during)
plt.show()
heatmap_during = sns.heatmap(data_during.corr(),xticklabels=lis2, yticklabels=lis2, annot=True, cmap='BrBG')
fig = heatmap_during.get_figure()
plt.show()
corr_matrix_during=data_during.corr()
#dist_matrix=math.sqrt(2*(1-corr_matrix))
print(corr_matrix_during)
#fig.savefig("correlation.png")
adf_during=pd.DataFrame(index=lis2)


for a in range(len(lis2)):
    
    adft=adfuller(data_during.dropna()[lis2[a]+" during_logreturn"])
    jbt=jarque_bera(data_during.dropna()[lis2[a]+' during_logreturn'])
    adf_during.loc[lis2[a],'ADF value']=adft[0]
    adf_during.loc[lis2[a],'P value']=adft[1]
    adf_during.loc[lis2[a],'Critical value 1%']=adft[4].get('1%')
    adf_during.loc[lis2[a],'Critical value 5%']=adft[4].get('5%')
    adf_during.loc[lis2[a],'Critical value 10%']=adft[4].get('10%')
    adf_during.loc[lis2[a],'JB Statistics']=jbt[0]
    print('\nADF test for logreturns on stock indice of '+lis2[a])
    print('ADF value is ',adft[0])
    print('Pvalue is ',adft[1])
    print('Critical values are ',adft[4])
    print('\nJB statistics for logreturns on stock indice of '+lis2[a],jbt[0])
print(adf_during.head())

# %%
import math
#finding skewness kurtosis JB statistics anf ADF unit test
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.stattools import jarque_bera
import seaborn as sns
#making a new empty dataframe which will not be having multi index columns with index as date then using for loop to add logreturns of all stock indices from the df which we found by concatenation
data_post=pd.DataFrame(index=df_post.index)
for t in range(len(lis2)):
    data_post[lis2[t]+' post_logreturn']=df_post[lis2[t]]['logreturn']
print(data_post.head())
hierarchical_post = sns.clustermap(data_post)
plt.show()
heatmap_post = sns.heatmap(data_post.corr(),xticklabels=lis2, yticklabels=lis2, annot=True, cmap='BrBG')
fig = heatmap_post.get_figure()
plt.show()
corr_matrix_post=data_post.corr()
#dist_matrix=math.sqrt(2*(1-corr_matrix))
print(corr_matrix_post)
#fig.savefig("correlation.png")
adf_post=pd.DataFrame(index=lis2)


for a in range(len(lis2)):
    
    adft=adfuller(data_post.dropna()[lis2[a]+" post_logreturn"])
    jbt=jarque_bera(data_post.dropna()[lis2[a]+' post_logreturn'])
    adf_post.loc[lis2[a],'ADF value']=adft[0]
    adf_post.loc[lis2[a],'P value']=adft[1]
    adf_post.loc[lis2[a],'Critical value 1%']=adft[4].get('1%')
    adf_post.loc[lis2[a],'Critical value 5%']=adft[4].get('5%')
    adf_post.loc[lis2[a],'Critical value 10%']=adft[4].get('10%')
    adf_post.loc[lis2[a],'JB Statistics']=jbt[0]
    print('\nADF test for logreturns on stock indice of '+lis2[a])
    print('ADF value is ',adft[0])
    print('Pvalue is ',adft[1])
    print('Critical values are ',adft[4])
    print('\nJB statistics for logreturns on stock indice of '+lis2[a],jbt[0])
print(adf_post.head())

# %%
dist_matrix=pd.DataFrame(index=corr_matrix.index,columns=corr_matrix.columns)

for i in corr_matrix.index:
    for j in corr_matrix.columns:
        dist_matrix.loc[i,j]=np.sqrt(2*(1-corr_matrix.loc[i,j]))
print(dist_matrix)

# %%
dist_matrix_pre=pd.DataFrame(index=corr_matrix_pre.index,columns=corr_matrix_pre.columns)

for i in corr_matrix_pre.index:
    for j in corr_matrix_pre.columns:
        dist_matrix_pre.loc[i,j]=np.sqrt(2*(1-corr_matrix_pre.loc[i,j]))
print(dist_matrix_pre)

# %%
dist_matrix_during=pd.DataFrame(index=corr_matrix_during.index,columns=corr_matrix_during.columns)

for i in corr_matrix_during.index:
    for j in corr_matrix_during.columns:
        dist_matrix_during.loc[i,j]=np.sqrt(2*(1-corr_matrix_during.loc[i,j]))
print(len(dist_matrix_during))
print(len(dist_matrix))

# %%
dist_matrix_post=pd.DataFrame(index=corr_matrix_post.index,columns=corr_matrix_post.columns)


for i in corr_matrix_post.index:
    for j in corr_matrix_post.columns:
        dist_matrix_post.loc[i,j]=np.sqrt(2*(1-corr_matrix_post.loc[i,j]))
print(dist_matrix_post)

# %%
"""In below graphs we have excluded china so in double for loop just instead of w in range 9 put 10 to include china as well """

import networkx as nx
G = nx.Graph()
#making the nodes without any edges
for ax in lis2:
    G.add_node(ax)
lis6=[]
lis5=[]
total_corr=0
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        total_corr+=corr_matrix.iloc[w,q]
        new_tup = (dist_matrix.iloc[w,q],lis2[w],lis2[q])
        lis5.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis5))
lis5=sorted(lis5)

for rt in lis5:
    tup=rt[::-1]
    lis6.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis6)
nx.draw(G,with_labels=True)
plt.show()
#t1=nx.minimum_spanning_edges(G)
tree=nx.minimum_spanning_tree(G)
nx.draw(tree, with_labels=True)
plt.figure()
plt.show()

# %%
G = nx.Graph()
for ax in lis2:
    G.add_node(ax)
lis8=[]
lis7=[]
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        if corr_matrix.iloc[w,q]>total_corr/100:
            new_tup = (dist_matrix.iloc[w,q],lis2[w],lis2[q])
            lis7.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis7))
lis7=sorted(lis7)

for rt in lis7:
    tup=rt[::-1]
    lis8.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis8)
nx.draw(G,with_labels=True)
plt.show()
print(nx.classes.function.density(G))
print(total_corr/100)
print(len(lis8))

# %%
#for pre
import networkx as nx
G = nx.Graph()
#making the nodes without any edges
for ax in lis2:
    G.add_node(ax)
lis6=[]
lis5=[]
total_corr_pre=0
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        total_corr_pre+=corr_matrix_pre.iloc[w,q]
        new_tup = (dist_matrix_pre.iloc[w,q],lis2[w],lis2[q])
        lis5.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis5))
lis5=sorted(lis5)

for rt in lis5:
    tup=rt[::-1]
    lis6.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis6)
nx.draw(G,with_labels=True)
plt.show()
#t1=nx.minimum_spanning_edges(G)
tree=nx.minimum_spanning_tree(G)
nx.draw(tree, with_labels=True)
plt.figure()
plt.show()

# %%
G = nx.Graph()
for ax in lis2:
    G.add_node(ax)
lis8=[]
lis7=[]
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        if corr_matrix_pre.iloc[w,q]>total_corr_pre/100:
            new_tup = (dist_matrix_pre.iloc[w,q],lis2[w],lis2[q])
            lis7.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis7))
lis7=sorted(lis7)

for rt in lis7:
    tup=rt[::-1]
    lis8.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis8)
nx.draw(G,with_labels=True)
plt.show()
print(nx.classes.function.density(G))
print(total_corr_pre/100)
print(len(lis8))

# %%
#for during
import networkx as nx
G = nx.Graph()
#making the nodes without any edges
for ax in lis2:
    G.add_node(ax)
lis6=[]
lis5=[]
total_corr_during=0
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        total_corr_during+=corr_matrix_during.iloc[w,q]
        new_tup = (dist_matrix_during.iloc[w,q],lis2[w],lis2[q])
        lis5.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis5))
lis5=sorted(lis5)

for rt in lis5:
    tup=rt[::-1]
    lis6.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis6)
nx.draw(G,with_labels=True)
plt.show()
#t1=nx.minimum_spanning_edges(G)
tree=nx.minimum_spanning_tree(G)
nx.draw(tree, with_labels=True)
plt.figure()
plt.show()

# %%
plt.figure(figsize=(30,30))
G = nx.Graph()
for ax in lis2:
    G.add_node(ax)
lis8=[]
lis7=[]
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        if corr_matrix_during.iloc[w,q]>total_corr_during/100:
            new_tup = (dist_matrix_during.iloc[w,q],lis2[w],lis2[q])
            lis7.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis7))
lis7=sorted(lis7)

for rt in lis7:
    tup=rt[::-1]
    lis8.append(tup)
#print(lis4)

G.add_weighted_edges_from(lis8)
nx.draw(G,with_labels=True)

plt.show()
print(nx.classes.function.density(G))
print(total_corr_during/100)
print(len(lis8))

# %%
#for post
import networkx as nx
G = nx.Graph()
#making the nodes without any edges
total_corr_post=0
for ax in lis2:
    G.add_node(ax)
lis6=[]
lis5=[]
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        total_corr_post+=corr_matrix_post.iloc[w,q]
        new_tup = (dist_matrix_post.iloc[w,q],lis2[w],lis2[q])
        lis5.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis5))
lis5=sorted(lis5)

for rt in lis5:
    tup=rt[::-1]
    lis6.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis6)
nx.draw(G,with_labels=True)
plt.show()
#t1=nx.minimum_spanning_edges(G)
tree=nx.minimum_spanning_tree(G)
nx.draw(tree, with_labels=True)
plt.figure()
plt.show()

# %%
G = nx.Graph()
for ax in lis2:
    G.add_node(ax)
lis8=[]
lis7=[]
#appending all the weights and corresponding node names into the list which will be used to make mst
for w in range(9):
    for q in range(w):
        if corr_matrix_post.iloc[w,q]>total_corr_post/100:
            new_tup = (dist_matrix_post.iloc[w,q],lis2[w],lis2[q])
            lis7.append(new_tup)
        #lis3.append(tup)
#print(sorted(lis4))new_tup = tuples[::-1]
print(sorted(lis7))
lis7=sorted(lis7)

for rt in lis7:
    tup=rt[::-1]
    lis8.append(tup)
#print(lis4)
G.add_weighted_edges_from(lis8)
nx.draw(G,with_labels=True)
plt.show()
print(nx.classes.function.density(G))
print(total_corr_post/100)
print(len(lis8))

# %%
covid=pd.read_csv('project under prof\WHO-COVID-19-global-data.csv',index_col='Date_reported')
#print(covid['Country'].unique())

print(covid.tail())

# %%
covid1=pd.DataFrame()
plt.figure(figsize=(20,15))
for t in ['India','Japan','Singapore','China','Pakistan','Republic of Korea','Indonesia','Malaysia','Philippines']:
#for t in ['India','Japan','Singapore','China','Bangladesh','Pakistan','Republic of Korea','Indonesia','Malaysia','Philippines']:
    covid2=covid[covid['Country']==t]
    covid2=covid2.loc["03-01-2020":"13-11-2020",'Cumulative_cases']
    print(covid2.shape)
    for j in range(1,46):
        covid1.loc[covid2.index[7*j],t+'_NewCases']=covid2.iloc[7*j]-covid2.iloc[7*(j-1)]
        #covid1.loc[covid2.index[7*j],t+'_Cases']=covid2.iloc[7*j]
    """fig,ax=plt.subplots()
    ax.plot(covid1.index,covid1[t+'_NewCases'])
    ax.set_xticklabels(covid1.index,rotation=90)
    ax.set_ylabel(t+' New Cases')
    fig.set_size_inches(14,9)
    plt.show()"""
    plt.plot(covid1.index,covid1[t+'_NewCases'])
    plt.xticks(covid1.index,rotation=90)


#got data of hong kong from 20 jan 2020 from wikipedia https://en.wikipedia.org/w/index.php?title=COVID-19_pandemic_in_Hong_Kong&action=edit&section=35
lis5=[0,2,3,0,3,0,0,2,2,1,1,1,0,3,3,3,2,0,10,6,7,1,3,3,0,1,3,2,3,4,0,1,5,6,4,6,2,1,1,5,1,0,4,0,3,2,5,1,5,9,2,6,4,7,9,10,25,16,48,17,44,39,30,24,43,65,64,59,41,32,51,37,43,17,28,24,21,25,13,16,11,4,5,3,4,1,4,2,2,0,4,4,2,0,2,0,0,0,0,0,2,0,0,1,0,0,4,0,0,3,0,0,3,1,1,0,3,0,0,0,8,2,0,0,0,0,1,0,13,3,2,3,6,0,6,3,3,1,1,0,0,0,1,1,0,3,0,8,4,3,1,3,30,16,2,14,3,1,2,4,2,28,9,5,11,10,17,14,24,42,38,28,38,52,48,19,67,58,64,107,73,61,113,118,123,133,128,145,106,118,149,121,124,115,78,80,85,95,89,69,72,69,33,62,69,48,46,74,44,36,26,18,27,26,25,9,19,24,21,13,18,15,9,12,8,8,12,7,21,11,6,6,12,12,13,19,14,4,9,9,3,13,23,6,8,3,7,2,1,6,10,4,8,10,7,4,5,11,8,11,18,8,6,7,11,8,0,12,7,17,4,15,5,8,11,4,5,6,8,5,2,3,7,3,7,6,9,3,7,6,3,10,6,9,18,23,6,8,14,8,4,9,12,26,43,68,73,80,85,81,92,84,115,76,82,103,90,112,101,95,78,100,104,112,86,69,95,82,98,82,96,70,109,74,85,63,53,71,57,59,70,61,53,54,68,42,35,41,53,32,25,33,45,59,31,41,60,42,29,38,50,55,107,56,77,70,61,81,76,73,64,60,39,50,28,53,34,25,19,22,37,19,27,32,26,17,21,24,12,12,9,8,16,8,13,15,20,16,12,17,13,24,33,22,14,13,14,9,11,8,16,9,21,8,22,60,47,24,30,18,11,10,13,8,8,18,12,10,9,11,6,1,8,7,6,13,19,2,7]
covid1.loc['10-01-2020','Hong Kong_NewCases']=0
covid1.loc['17-01-2020','Hong Kong_NewCases']=0
covid1.loc['24-01-2020','Hong Kong_NewCases']=8
for ms in range(4,46):
    covid1.loc[covid2.index[7*ms],'Hong Kong_NewCases']=sum(lis5[7*(ms-4)+5:7*(ms-3)+5])
#covid1['Hong Kong_Cases']=covid1['Hong Kong_NewCases'].cumsum()
plt.ylabel('Weekly New Covid Cases')  
plt.plot(covid1.index,covid1['Hong Kong_NewCases'])
plt.legend(['India','Japan','Singapore','China','Pakistan','South Korea','Indonesia','Malaysia','Philippines','Hong Kong'])
plt.show()

# %%
print(covid1.tail
      (20))

# %%
#peaks in each country till december 2020
covid2=covid1.loc[:'25-12-2020',:]
for j in covid2.columns:
    print(str(j)+' '+str(covid2[covid2.loc[:,j]==covid2.loc[:,j].max()].index)+' '+str(covid2.loc[:,j].max()))

# %%
#out of 15 weeks (from 7 aug to 13 nov) how many weeks each country's cases decreased
covid3=covid1.loc['07-08-2020':'13-11-2020',:]
print(len(covid3))
for j in covid3.columns:
    sum=0
    for k in covid3.index:
        if covid3.loc[k,j]<=covid3.loc['07-08-2020',j]:
            sum+=1
    print(str(j)+' '+str(sum))
